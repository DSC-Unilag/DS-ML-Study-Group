# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %% [markdown]
# # IMPORTING DATASETS

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
print(diabetes['DESCR']) #prints the description of the datasets
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, T-Cells (a type of white blood cells)
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, thyroid stimulating hormone
#       - s5      ltg, lamotrigine
# ...

# %%
df_diabetes = pd.DataFrame(np.c_[diabetes['data'], diabetes['target']], columns=(np.append(diabetes['feature_names'], ['target'])))

# %%
df_diabetes
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %%
df_diabetes.describe() #statical details of our datasets
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
df_diabetes.info() #shows the features of the dataset, also returns the null count and datatype of the features
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %% [markdown]
# # DATA VISUALIZATION

# %%
import seaborn as sns #A library for Data Visualization

# %%
plt.figure(figsize=(20,10)) #increase the size of the plot
sns.heatmap(df_diabetes.corr(), annot=True, cbar=None) #shows how the features correlate with one another

# %%
sns.pairplot(df_diabetes) #visualizes all features of the datasets

# %%
df_diabetes = df_diabetes.drop(['sex','s4'], axis=1) #drop irrevelant features in the DataFrame

# %%
df_diabetes
# Out:
#           age       bmi        bp        s1        s2        s3        s5  \
# 0    0.038076  0.061696  0.021872 -0.044223 -0.034821 -0.043401  0.019908
# 1   -0.001882 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.068330
# 2    0.085299  0.044451 -0.005671 -0.045599 -0.034194 -0.032356  0.002864
# 3   -0.089063 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.022692
# 4    0.005383 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.031991
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.019662  0.059744 -0.005697 -0.002566 -0.028674  0.031193
# 438 -0.005515 -0.015906 -0.067642  0.049341  0.079165 -0.028674 -0.018118
# 439  0.041708 -0.015906  0.017282 -0.037344 -0.013840 -0.024993 -0.046879
# 440 -0.045472  0.039062  0.001215  0.016318  0.015283 -0.028674  0.044528
# 441 -0.045472 -0.073030 -0.081414  0.083740  0.027809  0.173816 -0.004220
#
#            s6  target
# 0   -0.017646   151.0
# 1   -0.092204    75.0
# ...

# %% [markdown]
# # CREATING DEPENDENT AND INDEPENDENT VARIABLE

# %%
X = df_diabetes.drop(['target'], axis=1) #The dependent Variable 
y = df_diabetes['target'].values #Independent Variable

# %%
X
# Out:
#           age       bmi        bp        s1        s2        s3        s5  \
# 0    0.038076  0.061696  0.021872 -0.044223 -0.034821 -0.043401  0.019908
# 1   -0.001882 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.068330
# 2    0.085299  0.044451 -0.005671 -0.045599 -0.034194 -0.032356  0.002864
# 3   -0.089063 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.022692
# 4    0.005383 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.031991
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.019662  0.059744 -0.005697 -0.002566 -0.028674  0.031193
# 438 -0.005515 -0.015906 -0.067642  0.049341  0.079165 -0.028674 -0.018118
# 439  0.041708 -0.015906  0.017282 -0.037344 -0.013840 -0.024993 -0.046879
# 440 -0.045472  0.039062  0.001215  0.016318  0.015283 -0.028674  0.044528
# 441 -0.045472 -0.073030 -0.081414  0.083740  0.027809  0.173816 -0.004220
#
#            s6
# 0   -0.017646
# 1   -0.092204
# 2   -0.025930
# 3   -0.009362
# ...

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %% [markdown]
# # SPLITTING BOTH DEPENDENT AND INDEPENDENT TO TRAIN AND TEST SETS

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %% [markdown]
# # SCALING
#
# All features(dependent variables) were been standardized(scaled) in the dataset apart from the target, We can choose to scale the target(independent variable) or not if only we're using Linear Regression because Linear Regression will automatically scale the target(independent variable). Other models like KNN, Random Forest, Decision Trees does the same thing. if we use SVM without scaling the target variable the model will perform badly

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
y_train = scaler.fit_transform(y_train.reshape(-1,1))
y_test = scaler.transform(y_test.reshape(-1,1))

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.5549802264265007

# %%
model.coef_
# Out:
# array([[-0.35696567,  7.62835996,  3.34417804, -5.25471272,  2.97124737,
#         -0.30126448,  9.0687661 ,  0.10611523]])

# %%
model.intercept_
# Out:
# array([-0.00052481])

# %%
y_pred = scaler.inverse_transform(model.predict(X_test)) #reverts the scaling

# %%
y_pred
# Out:
# array([[-0.56006606],
#        [-0.37912699],
#        [ 1.17928123],
#        [-0.4571606 ],
#        [ 0.795221  ],
#        [ 0.18346499],
#        [ 0.65301218],
#        [-0.3419385 ],
#        [ 0.83216748],
#        [-1.10807025],
#        [-0.82533022],
#        [ 0.40344706],
#        [-0.6737849 ],
#        [ 0.19392417],
#        [-0.46860318],
#        [ 0.70987201],
#        [-0.47777307],
#        [ 0.1648456 ],
#        [ 1.13943387],
#        [-0.96443682],
#        [ 0.63229722],
#        [-0.73314227],
#        [ 0.74598722],
#        [-0.95642244],
#        [-0.51274891],
#        [-0.03930464],
#        [ 0.27246463],
#        [-0.17575087],
#        [ 0.25515533],
#        [-0.86934791],
#        [-0.12195649],
#        [-0.62057848],
#        [ 0.46013149],
#        [-0.41954034],
#        [-1.07890862],
#        [ 1.3223101 ],
#        [ 0.09343905],
#        [ 0.04340675],
#        [-1.22905857],
#        [ 0.38609585],
#        [-0.09810373],
# ...

# %%
# plt.figure(figsize=(20,10))
# plt.plot(X_train, y_train, '.', markersize=14)
# plt.plot(X_train, model.predict(X_train))
