# %%
#loading useful libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data directly from sklearn library
import sklearn.datasets

data = sklearn.datasets.load_diabetes(return_X_y=False, as_frame=False)

# %%
data1 = data.data
target= data.target

# %%
df = pd.DataFrame(data1)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#             7         8         9
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
target = pd.DataFrame(target)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       442 non-null    float64
#  1   1       442 non-null    float64
#  2   2       442 non-null    float64
#  3   3       442 non-null    float64
#  4   4       442 non-null    float64
#  5   5       442 non-null    float64
#  6   6       442 non-null    float64
#  7   7       442 non-null    float64
#  8   8       442 non-null    float64
#  9   9       442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.6 KB

# %%
df.describe()
# Out:
#                   0             1             2             3             4  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                   5             6             7             8             9
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# visulaize the correlation

sns.heatmap(df.corr())

# %%
# visualizing the correlation and distribution of the features

sns.pairplot(df)

# %%
# visualizing the distribution of the target

target.hist(bins = 20, figsize = (10,6))

plt.show()

# %%
# splitting the data set into train and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df,target, test_size= 0.3, random_state = 42)

# %%
#fitting a linear model on the set
from sklearn.linear_model import LinearRegression

lr = LinearRegression(fit_intercept =True)
lr.fit(X_train, y_train) #fit the model on the x,y data
# Out:
# LinearRegression()

# %%
prediction = lr.predict(X_test)

# %%
print(lr.intercept_)

print(lr.coef_)
# Out:
# [151.00818273]
# [[  29.25034582 -261.70768053  546.29737263  388.40077257 -901.95338706
#    506.761149    121.14845948  288.02932495  659.27133846   41.37536901]]

# %%
# Mean Squared Error 
from sklearn.metrics import mean_squared_error

MSE= mean_squared_error(y_test,prediction)

print(MSE)
# Out:
# 2821.7385595843775
